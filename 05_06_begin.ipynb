# %% [markdown]
# # Manual Hyperparameter Tuning a Neural Network
#
# ## Introduction
# In Challenge 4, we built a simple neural network using Keras. In this challenge, we will manually experiment with hyperarameters.
#
# This notebook contains the same workflow. Step 2 is the section that shows the simple 3-layer neural network from chapter 4. Section three is for you to change the same neural network by adding additional layers, neurons, and changing the number of epochs - then running the plot graph cell to see the results.
#
# NOTE: Be sure to re-run the begining cells before working on Section 3.
#
# ## Dataset
# The advertising dataset captures the sales revenue generated with respect to advertisement costs across numerous platforms like radio, TV, and newspapers.
#
# ### Features:
#
# #### Digital: advertising dollars spent on Internet.
# #### TV: advertising dollars spent on TV.
# #### Radio: advertising dollars spent on Radio.
# #### Newspaper: advertising dollars spent on Newspaper.
#
# ### Target (Label):
# #### Sales budget

# %% [markdown]
# # Step 1: Data Preparation

# %% [markdown]
# ### Import Libraries

# %%
# Import the necessary libraries

# For Data loading, Exploraotry Data Analysis, Graphing
import pandas as pd   # Pandas for data processing libraries
import numpy as np    # Numpy for mathematical functions

import matplotlib.pyplot as plt # Matplotlib for visualization tasks
import seaborn as sns # Seaborn for data visualization library based on matplotlib.
# %matplotlib inline

import sklearn        # ML tasks
from sklearn.model_selection import train_test_split # Split the dataset
from sklearn.metrics import mean_squared_error  # Calculate Mean Squared Error

# Build the Network
from tensorflow import keras
from keras.models import Sequential
#from tensorflow.keras.models import Sequential
from keras.layers import Dense

# %%
# Next, you read the dataset into a Pandas dataframe.

url = 'https://github.com/LinkedInLearning/artificial-intelligence-foundations-neural-networks-4381282/blob/main/Advertising_2023.csv?raw=true'
advertising_df= pd.read_csv(url,index_col=0)

# %%
# Pandas info() function is used to get a concise summary of the dataframe.
advertising_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1199 entries, 1 to 1197
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   digital    1199 non-null   float64
#  1   TV         1199 non-null   float64
#  2   radio      1199 non-null   float64
#  3   newspaper  1199 non-null   float64
#  4   sales      1199 non-null   float64
# dtypes: float64(5)
# memory usage: 56.2 KB

# %%
### Get summary of statistics of the data
advertising_df.describe()
# Out:
#            digital          TV        radio    newspaper        sales
# count  1199.000000  1199.00000  1199.000000  1199.000000  1199.000000
# mean    135.472394   146.61985    23.240617    30.529942    14.005505
# std     135.730821    85.61047    14.820827    21.712507     5.202804
# min       0.300000     0.70000     0.000000     0.300000     1.600000
# 25%      24.250000    73.40000     9.950000    12.800000    10.300000
# 50%      64.650000   149.70000    22.500000    25.600000    12.900000
# 75%     256.950000   218.50000    36.500000    45.100000    17.400000
# max     444.600000   296.40000    49.600000   114.000000    27.000000

# %%
#shape of dataframe - 1199 rows, five columns
advertising_df.shape
# Out:
# (1199, 5)

# %% [markdown]
# Let's check for any null values.

# %%
# The isnull() method is used to check and manage NULL values in a data frame.
advertising_df.isnull().sum()
# Out:
# digital      0
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Let's create some simple plots to check out the data!

# %%
## Plot the heatmap so that the values are shown.

plt.figure(figsize=(10,5))
sns.heatmap(advertising_df.corr(),annot=True,vmin=0,vmax=1,cmap='ocean')
# Out:
# <Axes: >

# %%
#create a correlation matrix
corr = advertising_df.corr()
plt.figure(figsize=(10, 5))
sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.7)],
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True)
plt.tight_layout()
display(plt.show())
# Out:
# None

# %%
advertising_df.corr()
# Out:
#             digital        TV     radio  newspaper     sales
# digital    1.000000  0.474256  0.041316   0.048023  0.380101
# TV         0.474256  1.000000  0.055697   0.055579  0.781824
# radio      0.041316  0.055697  1.000000   0.353096  0.576528
# newspaper  0.048023  0.055579  0.353096   1.000000  0.227039
# sales      0.380101  0.781824  0.576528   0.227039  1.000000

# %%
### Visualize Correlation

# Generate a mask for the upper triangle
mask = np.zeros_like(advertising_df.corr(), dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(advertising_df.corr(), mask=mask, cmap=cmap, vmax=.9, square=True, linewidths=.5, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# Since Sales is our target variable, we should identify which variable correlates the most with Sales.
#
# As we can see, TV has the highest correlation with Sales.
# Let's visualize the relationship of variables using scatterplots.

# %% [markdown]
# Rather than plot them separately, an efficient way to view the linear relationsips between variables is to use a "for loop" that plots all of the features at once.
#
# It seems there's no clear linear relationships between the predictors.
#
# At this point, we know that the variable TV will more likely give better prediction of Sales because of the high correlation and linearity of the two.

# %%
'''=== Show the linear relationship between features  and sales Thus, it provides that how the scattered
      they are and which features has more impact in prediction of house price. ==='''

# visiualize all variables  with sales
from scipy import stats
#creates figure
plt.figure(figsize=(18, 18))

for i, col in enumerate(advertising_df.columns[0:13]): #iterates over all columns except for price column (last one)
    plt.subplot(5, 3, i+1) # each row three figure
    x = advertising_df[col] #x-axis
    y = advertising_df['sales'] #y-axis
    plt.plot(x, y, 'o')

    # Create regression line
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1)) (np.unique(x)), color='red')
    plt.xlabel(col) # x-label
    plt.ylabel('sales') # y-label

# %% [markdown]
# Concluding results after observing the Graph
# The relation bw TV and Sales is stong and increases in linear fashion
# The relation bw Radio and Sales is less stong
# The relation bw TV and Sales is weak

# %% [markdown]
# ## Training a Linear Regression Model
#
# Regression is a supervised machine learning process.  It is similar to classification, but rather than predicting a label, you try to predict a continuous value.   Linear regression defines the relationship between a target variable (y) and a set of predictive features (x).  Simply stated, If you need to predict a number, then use regression.
#
# Let's now begin to train your regression model! You will need to first split up your data into an X array that contains the features to train on, and a y array with the target variable, in this case the Price column. You will toss out the Address column because it only has text info that the linear regression model can't use.

# %% [markdown]
# #### Data Preprocessing

# %% [markdown]
# ##### Split: X (features) and y (target)
# Next, let's define the features and label.  Briefly, feature is input; label is output. This applies to both classification and regression problems.

# %%
X = advertising_df[['digital', 'TV', 'radio', 'newspaper']]
y = advertising_df['sales']

# %% [markdown]
# ##### Scaling (Normalization)

# %%
'''=== Noramlization the features. Since it is seen that features have different ranges, it is best practice to
normalize/standarize the feature before using them in the model ==='''

#feature normalization
normalized_feature =  keras.utils.normalize(X.values)

# %% [markdown]
# ##### Train - Test - Split
#
# Now let's split the data into a training and test set.  Note:  Best pracices is to split into three - training, validation, and test set.
#
# By default - It splits the given data into 75-25 ratio

# %%
# Import train_test_split function from sklearn.model_selection
from sklearn.model_selection import train_test_split

# Split up the data into a training set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
print(X_train.shape,X_test.shape, y_train.shape, y_test.shape )
# Out:
# (719, 4) (480, 4) (719,) (480,)

# %% [markdown]
# # Step 2:  Build Network

# %% [markdown]
# #### Build and Train the Network

# %%
## Build Model (Building a three layer network - with one hidden layer)
model = Sequential()
model.add(Dense(4,input_dim=4, activation='relu'))                                                  # You don't have to specify input size.Just define the hidden layers
model.add(Dense(3,activation='relu'))

model.add(Dense(1))

# Compile Model
model.compile(optimizer='adam', loss='mse',metrics=['mse'])

#  Fit the Model
history = model.fit(X_train, y_train, validation_data = (X_test, y_test),
                    epochs = 32)
# Out:
# Epoch 1/32
# /home/rabi/linkedin/artificial-intelligence-foundations-neural-networks-4381282-1/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 203.1488 - mse: 203.1488 - val_loss: 167.3488 - val_mse: 167.3488
# Epoch 2/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 136.4725 - mse: 136.4725 - val_loss: 113.3583 - val_mse: 113.3583
# Epoch 3/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 107.8249 - mse: 107.8249 - val_loss: 112.1256 - val_mse: 112.1256
# Epoch 4/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 112.4692 - mse: 112.4692 - val_loss: 110.7883 - val_mse: 110.7883
# Epoch 5/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 107.3739 - mse: 107.3739 - val_loss: 109.2689 - val_mse: 109.2689
# Epoch 6/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 104.2202 - mse: 104.2202 - val_loss: 107.9159 - val_mse: 107.9159
# Epoch 7/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 111.5002 - mse: 111.5002 - val_loss: 106.9063 - val_mse: 106.9063
# Epoch 8/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 104.7277 - mse: 104.7277 - val_loss: 106.0032 - val_mse: 106.0032
# Epoch 9/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 106.4158 - mse: 106.4158 - val_loss: 105.0769 - val_mse: 105.0769
# Epoch 10/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 98.8774 - mse: 98.8774 - val_loss: 103.8637 - val_mse: 103.8637
# Epoch 11/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 98.1173 - mse: 98.1173 - val_loss: 102.5395 - val_mse: 102.5395
# Epoch 12/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 99.1264 - mse: 99.1264 - val_loss: 99.9418 - val_mse: 99.9418
# Epoch 13/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 105.0956 - mse: 105.0956 - val_loss: 97.8282 - val_mse: 97.8282
# Epoch 14/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 93.6395 - mse: 93.6395 - val_loss: 91.7721 - val_mse: 91.7721
# Epoch 15/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 84.8733 - mse: 84.8733 - val_loss: 82.2007 - val_mse: 82.2007
# Epoch 16/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 79.6027 - mse: 79.6027 - val_loss: 71.0452 - val_mse: 71.0452
# Epoch 17/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 63.8731 - mse: 63.8731 - val_loss: 61.7142 - val_mse: 61.7142
# Epoch 18/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55.4093 - mse: 55.4093 - val_loss: 51.8663 - val_mse: 51.8663
# Epoch 19/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.3350 - mse: 47.3350 - val_loss: 45.3680 - val_mse: 45.3680
# Epoch 20/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.6995 - mse: 40.6995 - val_loss: 40.0022 - val_mse: 40.0022
# Epoch 21/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39.7208 - mse: 39.7208 - val_loss: 36.4131 - val_mse: 36.4131
# Epoch 22/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.2509 - mse: 34.2509 - val_loss: 32.2764 - val_mse: 32.2764
# Epoch 23/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28.7936 - mse: 28.7936 - val_loss: 29.1857 - val_mse: 29.1857
# Epoch 24/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.8120 - mse: 26.8120 - val_loss: 25.9528 - val_mse: 25.9528
# Epoch 25/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.5329 - mse: 23.5329 - val_loss: 22.5979 - val_mse: 22.5979
# Epoch 26/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.3126 - mse: 19.3126 - val_loss: 20.0779 - val_mse: 20.0779
# Epoch 27/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.4082 - mse: 17.4082 - val_loss: 17.9610 - val_mse: 17.9610
# Epoch 28/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.4665 - mse: 14.4665 - val_loss: 16.2071 - val_mse: 16.2071
# Epoch 29/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.1633 - mse: 13.1633 - val_loss: 15.3235 - val_mse: 15.3235
# Epoch 30/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.2773 - mse: 14.2773 - val_loss: 13.7292 - val_mse: 13.7292
# Epoch 31/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.7351 - mse: 10.7351 - val_loss: 12.9551 - val_mse: 12.9551
# Epoch 32/32
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.8431 - mse: 10.8431 - val_loss: 12.1781 - val_mse: 12.1781

# %% [markdown]
# ### Visualization

# %% [markdown]
# You can add more 'flavor' to the graph by making it bigger and adding labels and names, as shown below.

# %%
## Plot a graph of model loss # show the graph of model loss in trainig and validation

plt.figure(figsize=(15,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss (MSE) on Training and Validation Data')
plt.ylabel('Loss-Mean Squred Error')
plt.xlabel('Epoch')
plt.legend(['Val Loss', 'Train Loss'], loc='upper right')
plt.show()

# %% [markdown]
# # Step 3:  Tune the Neural Network Hyperparameters

# %% [markdown]
# ## CHALLENGE: Manual Hyperparameter Tuning

# %% [markdown]
# Play with:
# 1. Adding additional layers
# 2. Adding additional neurons
# 3. Change the number of epochs.
#
# NOTE: After each change, run the cell to plot the graph and review the loss curves.

# %%
## Build Model
model = Sequential()
model.add(Dense(4,input_dim=4, activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(3, activation='relu'))
model.add(Dense(1))

# Compile Model
model.compile(optimizer='adam', loss='mse',metrics=['mse'])

#  Fit the Model
history = model.fit(X_train, y_train, validation_data = (X_test, y_test),
                    epochs = 128)
# Out:
# Epoch 1/128
# /home/rabi/linkedin/artificial-intelligence-foundations-neural-networks-4381282-1/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2463.2434 - mse: 2463.2434 - val_loss: 1558.9047 - val_mse: 1558.9047
# Epoch 2/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1384.9045 - mse: 1384.9045 - val_loss: 920.4496 - val_mse: 920.4496
# Epoch 3/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 781.3754 - mse: 781.3754 - val_loss: 558.3203 - val_mse: 558.3203
# Epoch 4/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 466.8108 - mse: 466.8108 - val_loss: 352.0450 - val_mse: 352.0450
# Epoch 5/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 323.0823 - mse: 323.0823 - val_loss: 227.0614 - val_mse: 227.0614
# Epoch 6/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 210.8489 - mse: 210.8489 - val_loss: 153.8151 - val_mse: 153.8151
# Epoch 7/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 164.4727 - mse: 164.4727 - val_loss: 106.7897 - val_mse: 106.7897
# Epoch 8/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 105.4081 - mse: 105.4081 - val_loss: 77.6504 - val_mse: 77.6504
# Epoch 9/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 81.2620 - mse: 81.2620 - val_loss: 57.8908 - val_mse: 57.8908
# Epoch 10/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.6501 - mse: 63.6501 - val_loss: 45.1819 - val_mse: 45.1819
# Epoch 11/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49.2889 - mse: 49.2889 - val_loss: 36.6125 - val_mse: 36.6125
# Epoch 12/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.2688 - mse: 41.2688 - val_loss: 31.3953 - val_mse: 31.3953
# Epoch 13/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35.6701 - mse: 35.6701 - val_loss: 28.0338 - val_mse: 28.0338
# Epoch 14/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34.7459 - mse: 34.7459 - val_loss: 25.8584 - val_mse: 25.8584
# Epoch 15/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 27.8708 - mse: 27.8708 - val_loss: 24.3209 - val_mse: 24.3209
# Epoch 16/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 27.0604 - mse: 27.0604 - val_loss: 23.1707 - val_mse: 23.1707
# Epoch 17/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.7384 - mse: 25.7384 - val_loss: 22.1362 - val_mse: 22.1362
# Epoch 18/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25.7677 - mse: 25.7677 - val_loss: 20.9794 - val_mse: 20.9794
# Epoch 19/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.0601 - mse: 23.0601 - val_loss: 19.0359 - val_mse: 19.0359
# Epoch 20/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.9342 - mse: 19.9342 - val_loss: 16.6560 - val_mse: 16.6560
# Epoch 21/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18.3500 - mse: 18.3500 - val_loss: 14.1511 - val_mse: 14.1511
# Epoch 22/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.2756 - mse: 14.2756 - val_loss: 12.0828 - val_mse: 12.0828
# Epoch 23/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.2979 - mse: 12.2979 - val_loss: 10.3858 - val_mse: 10.3858
# Epoch 24/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.8737 - mse: 11.8737 - val_loss: 9.0428 - val_mse: 9.0428
# Epoch 25/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3022 - mse: 9.3022 - val_loss: 8.1739 - val_mse: 8.1739
# Epoch 26/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8182 - mse: 8.8182 - val_loss: 7.4065 - val_mse: 7.4065
# Epoch 27/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1796 - mse: 7.1796 - val_loss: 6.8655 - val_mse: 6.8655
# Epoch 28/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7545 - mse: 7.7545 - val_loss: 6.4651 - val_mse: 6.4651
# Epoch 29/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8097 - mse: 6.8097 - val_loss: 6.1539 - val_mse: 6.1539
# Epoch 30/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4449 - mse: 5.4449 - val_loss: 5.9005 - val_mse: 5.9005
# Epoch 31/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2742 - mse: 6.2742 - val_loss: 5.6861 - val_mse: 5.6861
# Epoch 32/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1377 - mse: 6.1377 - val_loss: 5.5015 - val_mse: 5.5015
# Epoch 33/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5242 - mse: 5.5242 - val_loss: 5.3676 - val_mse: 5.3676
# Epoch 34/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6481 - mse: 5.6481 - val_loss: 5.2322 - val_mse: 5.2322
# Epoch 35/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9316 - mse: 4.9316 - val_loss: 5.1421 - val_mse: 5.1421
# Epoch 36/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3789 - mse: 5.3789 - val_loss: 5.0392 - val_mse: 5.0392
# Epoch 37/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2025 - mse: 5.2025 - val_loss: 4.9480 - val_mse: 4.9480
# Epoch 38/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9301 - mse: 4.9301 - val_loss: 4.9338 - val_mse: 4.9338
# Epoch 39/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2015 - mse: 5.2015 - val_loss: 4.8232 - val_mse: 4.8232
# Epoch 40/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9464 - mse: 4.9464 - val_loss: 4.7817 - val_mse: 4.7817
# Epoch 41/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6958 - mse: 4.6958 - val_loss: 4.7285 - val_mse: 4.7285
# Epoch 42/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6345 - mse: 4.6345 - val_loss: 4.6839 - val_mse: 4.6839
# Epoch 43/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0084 - mse: 4.0084 - val_loss: 4.6292 - val_mse: 4.6292
# Epoch 44/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2914 - mse: 4.2914 - val_loss: 4.5982 - val_mse: 4.5982
# Epoch 45/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2408 - mse: 4.2408 - val_loss: 4.5543 - val_mse: 4.5543
# Epoch 46/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8962 - mse: 4.8962 - val_loss: 4.5088 - val_mse: 4.5088
# Epoch 47/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5139 - mse: 4.5139 - val_loss: 4.4804 - val_mse: 4.4804
# Epoch 48/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9884 - mse: 3.9884 - val_loss: 4.4723 - val_mse: 4.4723
# Epoch 49/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0679 - mse: 4.0679 - val_loss: 4.4283 - val_mse: 4.4283
# Epoch 50/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7260 - mse: 4.7260 - val_loss: 4.4038 - val_mse: 4.4038
# Epoch 51/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1478 - mse: 4.1478 - val_loss: 4.3581 - val_mse: 4.3581
# Epoch 52/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6456 - mse: 4.6456 - val_loss: 4.3443 - val_mse: 4.3443
# Epoch 53/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0701 - mse: 4.0701 - val_loss: 4.3205 - val_mse: 4.3205
# Epoch 54/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8223 - mse: 3.8223 - val_loss: 4.2872 - val_mse: 4.2872
# Epoch 55/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6615 - mse: 4.6615 - val_loss: 4.2614 - val_mse: 4.2614
# Epoch 56/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5200 - mse: 3.5200 - val_loss: 4.2530 - val_mse: 4.2530
# Epoch 57/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9071 - mse: 3.9071 - val_loss: 4.2160 - val_mse: 4.2160
# Epoch 58/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2685 - mse: 4.2685 - val_loss: 4.1916 - val_mse: 4.1916
# Epoch 59/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8012 - mse: 3.8012 - val_loss: 4.1697 - val_mse: 4.1697
# Epoch 60/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3970 - mse: 4.3970 - val_loss: 4.1644 - val_mse: 4.1644
# Epoch 61/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9543 - mse: 3.9543 - val_loss: 4.1257 - val_mse: 4.1257
# Epoch 62/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8673 - mse: 3.8673 - val_loss: 4.1126 - val_mse: 4.1126
# Epoch 63/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6275 - mse: 3.6275 - val_loss: 4.0889 - val_mse: 4.0889
# Epoch 64/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7091 - mse: 3.7091 - val_loss: 4.0703 - val_mse: 4.0703
# Epoch 65/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7232 - mse: 3.7232 - val_loss: 4.0524 - val_mse: 4.0524
# Epoch 66/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7780 - mse: 3.7780 - val_loss: 4.0357 - val_mse: 4.0357
# Epoch 67/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8557 - mse: 3.8557 - val_loss: 4.0182 - val_mse: 4.0182
# Epoch 68/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9304 - mse: 3.9304 - val_loss: 3.9930 - val_mse: 3.9930
# Epoch 69/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0854 - mse: 4.0854 - val_loss: 3.9617 - val_mse: 3.9617
# Epoch 70/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8170 - mse: 3.8170 - val_loss: 3.9568 - val_mse: 3.9568
# Epoch 71/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8758 - mse: 3.8758 - val_loss: 3.9364 - val_mse: 3.9364
# Epoch 72/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6517 - mse: 3.6517 - val_loss: 3.9048 - val_mse: 3.9048
# Epoch 73/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5035 - mse: 3.5035 - val_loss: 3.9080 - val_mse: 3.9080
# Epoch 74/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5990 - mse: 3.5990 - val_loss: 3.8805 - val_mse: 3.8805
# Epoch 75/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5673 - mse: 3.5673 - val_loss: 3.8930 - val_mse: 3.8930
# Epoch 76/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7078 - mse: 3.7078 - val_loss: 3.8689 - val_mse: 3.8689
# Epoch 77/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5659 - mse: 3.5659 - val_loss: 3.8623 - val_mse: 3.8623
# Epoch 78/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2762 - mse: 3.2762 - val_loss: 3.8709 - val_mse: 3.8709
# Epoch 79/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3461 - mse: 3.3461 - val_loss: 3.8604 - val_mse: 3.8604
# Epoch 80/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5553 - mse: 3.5553 - val_loss: 3.8658 - val_mse: 3.8658
# Epoch 81/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8067 - mse: 3.8067 - val_loss: 3.8090 - val_mse: 3.8090
# Epoch 82/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4554 - mse: 3.4554 - val_loss: 3.8128 - val_mse: 3.8128
# Epoch 83/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2108 - mse: 3.2108 - val_loss: 3.8303 - val_mse: 3.8303
# Epoch 84/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3530 - mse: 3.3530 - val_loss: 3.7961 - val_mse: 3.7961
# Epoch 85/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6588 - mse: 3.6588 - val_loss: 3.8300 - val_mse: 3.8300
# Epoch 86/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5739 - mse: 3.5739 - val_loss: 3.7722 - val_mse: 3.7722
# Epoch 87/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5993 - mse: 3.5993 - val_loss: 3.7718 - val_mse: 3.7718
# Epoch 88/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4198 - mse: 3.4198 - val_loss: 3.7395 - val_mse: 3.7395
# Epoch 89/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5627 - mse: 3.5627 - val_loss: 3.7080 - val_mse: 3.7080
# Epoch 90/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2207 - mse: 3.2207 - val_loss: 3.7274 - val_mse: 3.7274
# Epoch 91/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4714 - mse: 3.4714 - val_loss: 3.6932 - val_mse: 3.6932
# Epoch 92/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2896 - mse: 3.2896 - val_loss: 3.6918 - val_mse: 3.6918
# Epoch 93/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4803 - mse: 3.4803 - val_loss: 3.6825 - val_mse: 3.6825
# Epoch 94/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5514 - mse: 3.5514 - val_loss: 3.6589 - val_mse: 3.6589
# Epoch 95/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2198 - mse: 3.2198 - val_loss: 3.6509 - val_mse: 3.6509
# Epoch 96/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3225 - mse: 3.3225 - val_loss: 3.6977 - val_mse: 3.6977
# Epoch 97/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2623 - mse: 3.2623 - val_loss: 3.6081 - val_mse: 3.6081
# Epoch 98/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9594 - mse: 2.9594 - val_loss: 3.6594 - val_mse: 3.6594
# Epoch 99/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1225 - mse: 3.1225 - val_loss: 3.6117 - val_mse: 3.6117
# Epoch 100/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9366 - mse: 2.9366 - val_loss: 3.5911 - val_mse: 3.5911
# Epoch 101/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0836 - mse: 3.0836 - val_loss: 3.5903 - val_mse: 3.5903
# Epoch 102/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2456 - mse: 3.2456 - val_loss: 3.5564 - val_mse: 3.5564
# Epoch 103/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1127 - mse: 3.1127 - val_loss: 3.5444 - val_mse: 3.5444
# Epoch 104/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2601 - mse: 3.2601 - val_loss: 3.5381 - val_mse: 3.5381
# Epoch 105/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9632 - mse: 2.9632 - val_loss: 3.5172 - val_mse: 3.5172
# Epoch 106/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9157 - mse: 2.9157 - val_loss: 3.5232 - val_mse: 3.5232
# Epoch 107/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9805 - mse: 2.9805 - val_loss: 3.5230 - val_mse: 3.5230
# Epoch 108/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0661 - mse: 3.0661 - val_loss: 3.4790 - val_mse: 3.4790
# Epoch 109/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9978 - mse: 2.9978 - val_loss: 3.5403 - val_mse: 3.5403
# Epoch 110/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0212 - mse: 3.0212 - val_loss: 3.4780 - val_mse: 3.4780
# Epoch 111/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0474 - mse: 3.0474 - val_loss: 3.4529 - val_mse: 3.4529
# Epoch 112/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2767 - mse: 3.2767 - val_loss: 3.4251 - val_mse: 3.4251
# Epoch 113/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0042 - mse: 3.0042 - val_loss: 3.4396 - val_mse: 3.4396
# Epoch 114/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7384 - mse: 2.7384 - val_loss: 3.4237 - val_mse: 3.4237
# Epoch 115/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8054 - mse: 2.8054 - val_loss: 3.4208 - val_mse: 3.4208
# Epoch 116/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8870 - mse: 2.8870 - val_loss: 3.3863 - val_mse: 3.3863
# Epoch 117/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7881 - mse: 2.7881 - val_loss: 3.3870 - val_mse: 3.3870
# Epoch 118/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4064 - mse: 2.4064 - val_loss: 3.3579 - val_mse: 3.3579
# Epoch 119/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0957 - mse: 3.0957 - val_loss: 3.3515 - val_mse: 3.3515
# Epoch 120/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7711 - mse: 2.7711 - val_loss: 3.3862 - val_mse: 3.3862
# Epoch 121/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6776 - mse: 2.6776 - val_loss: 3.3121 - val_mse: 3.3121
# Epoch 122/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9428 - mse: 2.9428 - val_loss: 3.3305 - val_mse: 3.3305
# Epoch 123/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8563 - mse: 2.8563 - val_loss: 3.3085 - val_mse: 3.3085
# Epoch 124/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8326 - mse: 2.8326 - val_loss: 3.2730 - val_mse: 3.2730
# Epoch 125/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6176 - mse: 2.6176 - val_loss: 3.2772 - val_mse: 3.2772
# Epoch 126/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6659 - mse: 2.6659 - val_loss: 3.2625 - val_mse: 3.2625
# Epoch 127/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5430 - mse: 2.5430 - val_loss: 3.2673 - val_mse: 3.2673
# Epoch 128/128
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7664 - mse: 2.7664 - val_loss: 3.2507 - val_mse: 3.2507

# %%
plt.figure(figsize=(15,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss (MSE) on Training and Validation Data')
plt.ylabel('Loss-Mean Squred Error')
plt.xlabel('Epoch')
plt.legend(['Val Loss', 'Train Loss'], loc='upper right')
plt.show()
